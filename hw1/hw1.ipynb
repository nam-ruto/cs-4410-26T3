# %% [markdown]
# # Homework 1: Working with the diamonds.csv Dataset
#
# This notebook completes the tasks for analyzing the diamonds dataset.

# %% [markdown]
# ## Task (a): Download diamonds.csv
#
# Note: The `diamonds.csv` dataset is already available in the current directory. If you need to download it, you can get it from:
# - Kaggle: https://www.kaggle.com/datasets?filetype=CSV
# - Rdatasets: https://vincentarelbundock.github.io/Rdatasets/datasets.html

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task (b): Load the dataset into a pandas DataFrame

# %%
# Load the dataset using the first column as the row index
df = pd.read_csv('diamonds.csv', index_col=0)
print(f"Dataset loaded successfully! Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
# Out:
# Dataset loaded successfully! Shape: (53940, 10)
# Columns: ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %% [markdown]
# ## Task (c): Display the first seven rows of the DataFrame

# %%
df.head(7)
# Out:
#           carat        cut color clarity  depth  table  price     x     y  \
# rownames
# 1          0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2          0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4          0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5          0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 6          0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 7          0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
#
#              z
# rownames
# 1         2.43
# 2         2.31
# 3         2.31
# 4         2.63
# 5         2.75
# 6         2.48
# 7         2.47

# %% [markdown]
# ## Task (d): Display the last seven rows of the DataFrame

# %%
df.tail(7)
# Out:
#           carat        cut color clarity  depth  table  price     x     y  \
# rownames
# 53934      0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
# 53935      0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73
# 53936      0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53937      0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53938      0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53939      0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53940      0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#              z
# rownames
# 53934     3.49
# 53935     3.58
# 53936     3.50
# 53937     3.61
# 53938     3.56
# 53939     3.74
# 53940     3.64

# %% [markdown]
# ## Task (e): Descriptive statistics for numerical columns

# %%
# Select numerical columns: carat, depth, table, price, x, y, z
numerical_cols = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']
df[numerical_cols].describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ## Task (f): Descriptive statistics for categorical columns

# %%
# Descriptive statistics for categorical columns: cut, color, clarity
categorical_cols = ['cut', 'color', 'clarity']

for col in categorical_cols:
    print(f"\n{col.upper()}:")
    print(df[col].describe())
    print("-" * 50)
# Out:
# CUT:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object
# --------------------------------------------------
#
# COLOR:
# count     53940
# unique        7
# top           G
# freq      11292
# Name: color, dtype: object
# --------------------------------------------------
#
# CLARITY:
# count     53940
# unique        8
# top         SI1
# freq      13065
# Name: clarity, dtype: object
# --------------------------------------------------

# %% [markdown]
# ## Task (g): Unique category values

# %%
# Find unique values for each categorical column
for col in categorical_cols:
    unique_vals = df[col].unique()
    print(f"\n{col.upper()} unique values ({len(unique_vals)}):")
    print(sorted(unique_vals))
    print("-" * 50)
# Out:
# CUT unique values (5):
# ['Fair', 'Good', 'Ideal', 'Premium', 'Very Good']
# --------------------------------------------------
#
# COLOR unique values (7):
# ['D', 'E', 'F', 'G', 'H', 'I', 'J']
# --------------------------------------------------
#
# CLARITY unique values (8):
# ['I1', 'IF', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2']
# --------------------------------------------------

# %% [markdown]
# ## Task (h): Histograms for numerical columns

# %%
# Enable matplotlib support in IPython
# %matplotlib inline

# Create histograms for all numerical columns
df[numerical_cols].hist(figsize=(15, 10), bins=50)
plt.tight_layout()
plt.show()
